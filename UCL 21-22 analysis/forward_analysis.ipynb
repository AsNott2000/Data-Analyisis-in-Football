# %%
import numpy as np
import pandas as pd
import seaborn as sns

df_attacking = pd.read_csv("ucl_2122_datasets/attacking.csv")
df_attempts = pd.read_csv("ucl_2122_datasets/attempts.csv")
df_defending = pd.read_csv("ucl_2122_datasets/defending.csv")
df_disciplin = pd.read_csv("ucl_2122_datasets/disciplinary.csv")
df_distributon = pd.read_csv("ucl_2122_datasets/distributon.csv")
df_goals = pd.read_csv("ucl_2122_datasets/goals.csv")
df_keystats = pd.read_csv("ucl_2122_datasets/key_stats.csv")

# %%
attacking_forward = df_attacking[df_attacking["position"] == "Forward"]
attempts_forward = df_attempts[df_attempts["position"] == "Forward"]
defending_forward = df_defending[df_defending["position"] == "Forward"]
disciplin_forward = df_disciplin[df_disciplin["position"] == "Forward"]
distributon_forward = df_distributon[df_distributon["position"] == "Forward"]
goals_forward = df_goals[df_goals["position"] == "Forward"]
keystats_forward = df_keystats[df_keystats["position"] == "Forward"]

# %%
attacking_forward.head()
#mac basina asist
#en cok korner kullanan forvet
#en cok ofsayta dusen
#en cok dribbleing yapan
# Out:
#     serial      player_name         club position  assists  corner_taken  \
# 1        2  Vinícius Júnior  Real Madrid  Forward        6             3
# 3        4           Antony         Ajax  Forward        5             3
# 8        5           Mbappé        Paris  Forward        4             4
# 9        5    Gerard Moreno   Villarreal  Forward        4             0
# 13      12           Müller       Bayern  Forward        3            10
#
#     offsides  dribbles  match_played
# 1          4        83            13
# 3          4        28             7
# 8          8        43             8
# 9          3         9             7
# 13         8         2            10

# %%
attempts_forward.head()
#targetlarin attemptse orani
#mac basina attempts
#gollerle attemptslerin orani
# Out:
#    serial  player_name         club position  total_attempts  on_target  \
# 0       1      Benzema  Real Madrid  Forward              45         23
# 1       2        Salah    Liverpool  Forward              42         22
# 4       5  Lewandowski       Bayern  Forward              31         19
# 5       6    Luis Díaz        Porto  Forward              29         11
# 6       7     Martínez        Inter  Forward              28          7
#
#    off_target  blocked  match_played
# 0          13        9            12
# 1          11        9            13
# 4           8        4            10
# 5           7       11            13
# 6          10       11             8

# %%
defending_forward.head()
#clearence = uzaklastirma
#balls recovery = top calma
#tackles = kayarak mudahele
# Out:
#      serial      player_name         club position  balls_recoverd  tackles  \
# 123     121  Vinícius Júnior  Real Madrid  Forward              29       11
# 153     151           Antony         Ajax  Forward              25        7
# 189     189       Rafa Silva      Benfica  Forward              21       12
# 196     189       João Mário        Porto  Forward              21        1
# 197     198        Griezmann     Atlético  Forward              20       14
#
#      t_won  t_lost  clearance_attempted  match_played
# 123      3       8                    0            13
# 153      3       4                    2             7
# 189      6       6                    1             9
# 196      0       1                    6             4
# 197      6       8                    5             9

# %%
disciplin_forward.head()
#commited = yapilan
#fouls suffered = alinan
# Out:
#     serial      player_name         club position  fouls_committed  \
# 9        6           Haller         Ajax  Forward               17
# 13      12        Luis Díaz        Porto  Forward               16
# 21      20         Sterling    Man. City  Forward               14
# 25      26  Vinícius Júnior  Real Madrid  Forward               13
# 40      40      Lewandowski       Bayern  Forward               11
#
#     fouls_suffered  red  yellow  minutes_played  match_played
# 9               11    1       0             668             8
# 13              10    1       0             908            13
# 21              10    1       0             581            12
# 25              24    1       0            1199            13
# 40              13    1       0             876            10

# %%
distributon_forward.head()
# Out:
#      serial    player_name         club position  pass_accuracy  \
# 25       24  Matheus Cunha     Atlético  Forward           93.6
# 34       34       Minamino    Liverpool  Forward           93.0
# 71       71         Correa        Inter  Forward           90.8
# 84       80          Jović  Real Madrid  Forward           90.3
# 101      95        Reinier     Dortmund  Forward           90.0
#
#      pass_attempted  pass_completed  cross_accuracy  cross_attempted  \
# 25               19              17               0                0
# 34               76              69               0                1
# 71               27              24               0                1
# 84               40              36               0                0
# 101              71              64               0                1
#
#      cross_complted  freekicks_taken  match_played
# 25                0                0             5
# 34                0                1             4
# ...

# %%
goals_forward.head()
# Out:
#    serial  player_name         club position  goals  right_foot  left_foot  \
# 0       1      Benzema  Real Madrid  Forward     15          11          1
# 1       2  Lewandowski       Bayern  Forward     13           8          3
# 2       3       Haller         Ajax  Forward     11           3          4
# 3       4        Salah    Liverpool  Forward      8           0          8
# 6       7       Mbappé        Paris  Forward      6           6          0
#
#    headers  others  inside_area  outside_areas  penalties  match_played
# 0        3       0           13              2          3            12
# 1        1       1           13              0          3            10
# 2        3       1           11              0          1             8
# 3        0       0            7              1          1            13
# 6        0       0            6              0          0             8

# %%
keystats_forward.head()
# Out:
#         player_name         club position  minutes_played  match_played  \
# 1   Vinícius Júnior  Real Madrid  Forward            1199            13
# 2           Benzema  Real Madrid  Forward            1106            12
# 12          Rodrygo  Real Madrid  Forward             505            11
# 15          Asensio  Real Madrid  Forward             207             8
# 16            Jović  Real Madrid  Forward             113             3
#
#     goals  assists distance_covered
# 1       4        6            133.0
# 2      15        1            121.5
# 12      5        2             65.7
# 15      1        2             28.4
# 16      0        0             12.9
